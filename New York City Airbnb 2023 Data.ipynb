# %%
# !pip install -U pandasql

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandasql import sqldf

# %%
df = pd.read_csv(r"C:\Users\USER\Documents\Dataset Exercise for Data Science\NYC-Airbnb-2023.csv")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4828\2731363155.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\USER\Documents\Dataset Exercise for Data Science\NYC-Airbnb-2023.csv")

# %%
df.head(5)
# Out:
#      id                                         name  host_id  host_name  \
# 0  2595                        Skylit Midtown Castle     2845   Jennifer
# 1  5121                              BlissArtsSpace!     7356      Garon
# 2  5203           Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 3  5178             Large Furnished Room Near B'way　     8967   Shunichi
# 4  5136  Large Sunny Brooklyn Duplex, Patio + Garden     7378    Rebecca
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2           Manhattan     Upper West Side  40.80380  -73.96751
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4            Brooklyn         Sunset Park  40.66265  -73.99454
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#SQL Playground

query = "SELECT * FROM df LIMIT 5"
sqldf(query, env=None)
# Out:
#      id                                         name  host_id  host_name  \
# 0  2595                        Skylit Midtown Castle     2845   Jennifer
# 1  5121                              BlissArtsSpace!     7356      Garon
# 2  5203           Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 3  5178             Large Furnished Room Near B'way　     8967   Shunichi
# 4  5136  Large Sunny Brooklyn Duplex, Patio + Garden     7378    Rebecca
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2           Manhattan     Upper West Side  40.80380  -73.96751
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4            Brooklyn         Sunset Park  40.66265  -73.99454
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
plt.figure(figsize=(9, 5))
sns.countplot(data=df, y='neighbourhood_group')
plt.xlabel('count')
plt.ylabel('neighbourhood_group')
# Out:
# Text(0, 0.5, 'neighbourhood_group')

# %%
df.plot(kind ="scatter" , x = "longitude" , y = "latitude")
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1, figsize = (10, 6))
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(9, 5))
sns.countplot(data=df, y='room_type')
plt.xlabel('count')
plt.ylabel('room_type')
# Out:
# Text(0, 0.5, 'room_type')

# %%
sns.boxplot(x=df["price"])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df["price"].describe()
# Out:
# count    42931.000000
# mean       200.307167
# std        895.082911
# min          0.000000
# 25%         75.000000
# 50%        125.000000
# 75%        200.000000
# max      99000.000000
# Name: price, dtype: float64

# %%
sns.boxplot(x=df["minimum_nights"])
# Out:
# <AxesSubplot:xlabel='minimum_nights'>

# %%
df["minimum_nights"].describe()
# Out:
# count    42931.000000
# mean        18.111178
# std         27.462513
# min          1.000000
# 25%          2.000000
# 50%          7.000000
# 75%         30.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
sns.boxplot(x=df["number_of_reviews"])
# Out:
# <AxesSubplot:xlabel='number_of_reviews'>

# %%
df["number_of_reviews"].describe()
# Out:
# count    42931.000000
# mean        25.856001
# std         56.616344
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max       1842.000000
# Name: number_of_reviews, dtype: float64

# %%
sns.boxplot(x=df["reviews_per_month"])
# Out:
# <AxesSubplot:xlabel='reviews_per_month'>

# %%
df["reviews_per_month"].describe()
# Out:
# count    32627.000000
# mean         1.168988
# std          1.789675
# min          0.010000
# 25%          0.140000
# 50%          0.520000
# 75%          1.670000
# max         86.610000
# Name: reviews_per_month, dtype: float64

# %%
sns.boxplot(x=df["calculated_host_listings_count"])
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count'>

# %%
df['host_id'].nunique()
# Out:
# 27455

# %%
df2 = df[df['calculated_host_listings_count'] > 1]
df2
# Out:
#                        id                                               name  \
# 0                    2595                              Skylit Midtown Castle
# 1                    5121                                    BlissArtsSpace!
# 7                    5803      Lovely, Cozy, Room 1, BEST AREA; Legal Rental
# 8                   31130                             Most Central Location!
# 10                   6872  Uptown Sanctuary w/ Private Bath (Month to Month)
# ...                   ...                                                ...
# 42921  839542253443554475          Charming Private BD w/shared BR & Kitchen
# 42923  839607315156742936         Spacious private BD w/ shared BR & Kitchen
# 42927  839786573617495393     Room in the heart of LES with Gym& Rooftop BBQ
# 42928  839797749155954018                      Fantastic 3BD apt in Brooklyn
# 42930  839817199240589949                                         378-2L-Red
#
# ...

# %%
df["calculated_host_listings_count"].describe()
# Out:
# count    42931.000000
# mean        24.054809
# std         80.867958
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# max        526.000000
# Name: calculated_host_listings_count, dtype: float64

# %%
sns.boxplot(data = df, x = "room_type", y = "calculated_host_listings_count")
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='calculated_host_listings_count'>

# %%
#Data cleaning
q1 = df['price'].quantile(0.99)
df = df[df['price'] < q1]

q2 = df['minimum_nights'].quantile(0.99)
df = df[df['minimum_nights'] < q2]

q3 = df['number_of_reviews'].quantile(0.99)
df = df[df['number_of_reviews'] < q3]

q4 = df['reviews_per_month'].quantile(0.99)
df = df[df['reviews_per_month'] < q4]

q5 = df['calculated_host_listings_count'].quantile(0.99)
df = df[df['calculated_host_listings_count'] < q5]

# %%
sns.boxplot(x=df["price"])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(x=df["minimum_nights"])
# Out:
# <AxesSubplot:xlabel='minimum_nights'>

# %%
sns.boxplot(x=df["number_of_reviews"])
# Out:
# <AxesSubplot:xlabel='number_of_reviews'>

# %%
sns.boxplot(x=df["reviews_per_month"])
# Out:
# <AxesSubplot:xlabel='reviews_per_month'>

# %%
sns.boxplot(x=df["calculated_host_listings_count"])
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count'>

# %%
sns.boxplot(data=df, x='room_type', y='price')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %%
sns.boxplot(data=df, x='room_type', y='minimum_nights')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='minimum_nights'>

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='price', palette='viridis')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sns.boxplot(data=df, x='room_type', y='calculated_host_listings_count')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='calculated_host_listings_count'>

# %%
dataplot=sns.heatmap(df.corr(), cmap = "Blues", annot=True)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='minimum_nights', palette='viridis')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df3 = df[df['minimum_nights'] > 6]
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df3, x='longitude', y='latitude', hue='minimum_nights', palette='viridis')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
df.plot(kind ="scatter" , x = "minimum_nights" , y = "reviews_per_month")
# Out:
# <AxesSubplot:xlabel='minimum_nights', ylabel='reviews_per_month'>

# %%
df.plot(kind ="scatter" , x = "minimum_nights" , y = "reviews_per_month", alpha=0.1, figsize = (10, 6))
# Out:
# <AxesSubplot:xlabel='minimum_nights', ylabel='reviews_per_month'>

# %%
sns.boxplot(data=df, x='neighbourhood_group', y='calculated_host_listings_count')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='calculated_host_listings_count'>

# %%
df4 = df[df['calculated_host_listings_count'] > 10]

# %%
grouped = df.groupby(['neighbourhood_group', 'host_id'], as_index=False).size()

# Group by neighborhood and sum the aggregated number_of_listings
total_listings_by_neighbourhood_group = grouped.groupby('neighbourhood_group').sum().reset_index()
total_listings_by_neighbourhood_group.rename(columns={'size': 'count'}, inplace=True)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=total_listings_by_neighbourhood_group, x='neighbourhood_group', y='count')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
df5 = df[df['calculated_host_listings_count'] > 10]

# %%
grouped = df5.groupby(['neighbourhood_group', 'host_id'], as_index=False).size()

# Group by neighborhood and sum the aggregated number_of_listings
total_listings_by_neighbourhood_group = grouped.groupby('neighbourhood_group').sum().reset_index()
total_listings_by_neighbourhood_group.rename(columns={'size': 'count'}, inplace=True)

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=total_listings_by_neighbourhood_group, x='neighbourhood_group', y='count')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>
